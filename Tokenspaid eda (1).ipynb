# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df1 = pd.read_csv(r"C:\Users\DELL\Downloads\TokensPaidWithoutLeadID.csv")
df2 = pd.read_csv(r"C:\Users\DELL\Downloads\TokensPaidWithLeadID.csv")

# %%
print(df1.head())
# Out:
#       Name created_date   paid_date    cohort              source  \
# 0  sudheer   2023-08-25  2023-08-30  cohort 1            linkedin
# 1   swathi   2023-09-19  2023-10-06  cohort 1            linkedin
# 2    kabir   2024-03-21  2024-03-23  cohort 2  inbound phone call
# 3   vikash   2023-08-05  2023-08-14  cohort 1            linkedin
# 4     amir   2023-08-07  2023-08-08  cohort 1        zoom webinar
#
#                agent        counsellor                           prospect_id  \
# 0    shaqlain sheikh  shailendra singh  d7d7ba30-8207-4a00-a2f0-72c9718a9ad7
# 1              rohit             aarti  9f8bb6d3-d30e-4f73-baa8-8e1ae4dd3517
# 2  siddharth goswami     aviral sharma  0acf038e-e696-11ee-807d-02e22ea38447
# 3    shaqlain sheikh            zareen  aa13b8b9-cff5-41fe-a1f5-353e4c90ab04
# 4    shaqlain sheikh  shailendra singh  b78be1f5-34f1-11ee-a17b-0a9468bc4542
#
#            status
# 0  INACTIVE TOKEN
# 1  INACTIVE TOKEN
# 2    active token
# 3  INACTIVE TOKEN
# 4  INACTIVE TOKEN

# %%
df2.head()
# Out:
#        Name                                 Lead ID created_date   paid_date  \
# 0     srija                      l:1501566724035844   2024-04-13  2024-05-02
# 1    satyam  d552642c-6784-4d5d-a545-0e926458e848-3   2024-03-18  2024-03-19
# 2     tanya                       l:900041774843171   2023-11-30  2023-12-12
# 3    ashish                      l:1293647514650937   2023-12-06  2023-12-13
# 4  satheesh                      l:1519452715578667   2024-02-18  2024-03-15
#
#      cohort    source                 agent        counsellor  \
# 0  cohort 2  facebook          payal dhiman          shashwat
# 1  cohort 2  linkedin          payal dhiman  shailendra singh
# 2  cohort 2  facebook  vaibhav kumar sharma   diptikanta jena
# 3  cohort 2  facebook  vaibhav kumar sharma   diptikanta jena
# 4  cohort 2  facebook          sagar tiwari  shailendra singh
#
#                             prospect_id        status
# 0  23d84277-bb77-4b58-a9ee-2d36c4c7ac76  active token
# 1  9534b162-f601-4a4c-aa56-03f71d73a652  active token
# 2  fc411dd9-9a3c-43af-b9a4-e9155e756031  active token
# 3  40deb473-11f6-4da6-9fd0-75f1f3075b86  active token
# 4  b12ebd59-c99e-45c9-b278-45764fe7f5cb  active token

# %%
df1.dtypes
# Out:
# Name            object
# created_date    object
# paid_date       object
# cohort          object
# source          object
# agent           object
# counsellor      object
# prospect_id     object
# status          object
# dtype: object

# %%
df2.dtypes
# Out:
# Name            object
# Lead ID         object
# created_date    object
# paid_date       object
# cohort          object
# source          object
# agent           object
# counsellor      object
# prospect_id     object
# status          object
# dtype: object

# %%
df1['agent'].describe()
# Out:
# count                     258
# unique                     42
# top       fahim moshin shaikh
# freq                       34
# Name: agent, dtype: object

# %%
df1[['created_date', 'paid_date']].describe(datetime_is_numeric=True)
# Out:
#        created_date   paid_date
# count           258         258
# unique          148         126
# top      2024-01-27  2024-02-11
# freq             22           7

# %%
df1.describe(include=[object])
# Out:
#            Name created_date   paid_date    cohort    source  \
# count       258          258         258       258       258
# unique      234          148         126         2        22
# top     saurabh   2024-01-27  2024-02-11  cohort 2  facebook
# freq          3           22           7       232        82
#
#                       agent        counsellor  \
# count                   258               258
# unique                   42                12
# top     fahim moshin shaikh  shailendra singh
# freq                     34                71
#
#                                  prospect_id        status
# count                                    258           258
# unique                                   258             2
# top     d7d7ba30-8207-4a00-a2f0-72c9718a9ad7  active token
# freq                                       1           232

# %%
df1.isnull().sum()
# Out:
# Name            0
# created_date    0
# paid_date       0
# cohort          0
# source          0
# agent           0
# counsellor      0
# prospect_id     0
# status          0
# dtype: int64

# %%
df2.isnull().sum()
# Out:
# Name            0
# Lead ID         0
# created_date    0
# paid_date       0
# cohort          0
# source          0
# agent           0
# counsellor      0
# prospect_id     0
# status          0
# dtype: int64

# %%
print(df1['source'].value_counts())
# Out:
# facebook                       82
# linkedin                       48
# zoom webinar                   37
# 1% club                        24
# referral                       17
# us pathway                      9
# n-db                            7
# futurense usp - website         7
# placement drive                 6
# b.tech 19-20 grad               4
# googleads                       4
# usp support                     3
# inbound phone call              1
# futurense employee referral     1
# 1% club/ b.tech 19-20 grad      1
# lpu                             1
# website                         1
# calendly                        1
# ig                              1
# fb lead ads                     1
# os                              1
# 17th sept hot leads             1
# Name: source, dtype: int64

# %%
df1['cohort'].value_counts()
# Out:
# cohort 2    232
# cohort 1     26
# Name: cohort, dtype: int64

# %%
def filter_data(df, column_name, input_value):
    filtered_data = df[df[column_name] == input_value]
    return filtered_data

print("Enter the column you want to filter by (source, agent, counsellor):")
column_name = input().strip()

print(f"Enter the {column_name} you want to filter by:")
input_value = input().strip()
df1 = filter_data(df1, column_name, input_value)
print("Filtered Data (Without Lead ID):")
print(df1)
# Out:
# Enter the column you want to filter by (source, agent, counsellor):
# agent
# Enter the agent you want to filter by:
# fahim moshin shaikh
# Filtered Data (Without Lead ID):
#             Name created_date   paid_date    cohort               source  \
# 41     srinithya   2023-12-22  2024-01-01  cohort 2             linkedin
# 42       karthik   2024-01-13  2024-01-19  cohort 2             referral
# 49       swapnil   2023-08-27  2023-09-05  cohort 1             linkedin
# 50      abhishek   2023-09-05  2023-09-27  cohort 1             facebook
# 55       shobhit   2024-01-27  2024-03-04  cohort 2              1% club
# 74         tejas   2023-09-18  2024-04-06  cohort 2             linkedin
# 78        sachin   2023-09-29  2024-01-02  cohort 2             linkedin
# 87         anand   2023-09-09  2023-10-05  cohort 1             linkedin
# 89       hariraj   2023-09-25  2023-09-19  cohort 1         zoom webinar
# 91       nisanth   2023-09-09  2023-10-11  cohort 1      placement drive
# 102  pushpalatha   2023-09-07  2023-09-18  cohort 1             facebook
# 111        arbaz   2023-12-06  2024-02-20  cohort 2             facebook
# 123  venkateswar   2023-10-07  2024-03-03  cohort 2             linkedin
# 125     mohammed   2024-01-12  2024-02-09  cohort 2             facebook
# 132        sneha   2024-01-27  2024-03-03  cohort 2              1% club
# 133      shwetha   2024-01-27  2024-02-01  cohort 2              1% club
# 143    vaishnavi   2024-01-19  2024-02-15  cohort 2             facebook
# 146    dakshansh   2023-09-11  2024-01-25  cohort 2             facebook
# 147       mukesh   2023-06-29  2024-02-03  cohort 2                 n-db
# 152    arunkumar   2023-10-17  2023-12-20  cohort 2             linkedin
# 155      nitasha   2023-08-24  2023-10-10  cohort 1         zoom webinar
# 160      bharath   2023-09-25  2024-02-05  cohort 2      placement drive
# 161     rajendra   2024-01-09  2024-01-22  cohort 2             facebook
# 175      aneesur   2023-09-09  2024-01-16  cohort 2      placement drive
# 179        sagar   2023-10-17  2023-10-31  cohort 2             linkedin
# 182      chintan   2023-09-14  2023-10-03  cohort 1  17th sept hot leads
# 183      chintan   2023-08-29  2024-02-01  cohort 2             facebook
# 184     akanksha   2023-01-04  2024-01-29  cohort 2             facebook
# 191      nishant   2023-12-10  2024-01-12  cohort 2             facebook
# 195       sambit   2023-08-17  2024-01-17  cohort 2             linkedin
# 200      sushant   2023-08-14  2023-12-29  cohort 2             linkedin
# 222      rashika   2024-02-15  2024-03-22  cohort 2             referral
# 242    sreekumar   2023-08-18  2023-12-17  cohort 2             linkedin
# 243       divesh   2023-12-30  2024-04-11  cohort 2             facebook
#
#                    agent        counsellor  \
# 41   fahim moshin shaikh  shailendra singh
# 42   fahim moshin shaikh  shailendra singh
# 49   fahim moshin shaikh  shailendra singh
# 50   fahim moshin shaikh  shailendra singh
# 55   fahim moshin shaikh  shailendra singh
# 74   fahim moshin shaikh          shashwat
# 78   fahim moshin shaikh   diptikanta jena
# 87   fahim moshin shaikh  shailendra singh
# 89   fahim moshin shaikh  shailendra singh
# 91   fahim moshin shaikh  shailendra singh
# 102  fahim moshin shaikh  shailendra singh
# 111  fahim moshin shaikh  shailendra singh
# 123  fahim moshin shaikh  shailendra singh
# 125  fahim moshin shaikh   diptikanta jena
# 132  fahim moshin shaikh  shailendra singh
# 133  fahim moshin shaikh     aviral sharma
# 143  fahim moshin shaikh  shailendra singh
# 146  fahim moshin shaikh  shailendra singh
# 147  fahim moshin shaikh  shailendra singh
# 152  fahim moshin shaikh  shailendra singh
# 155  fahim moshin shaikh  shailendra singh
# 160  fahim moshin shaikh  shailendra singh
# 161  fahim moshin shaikh  shailendra singh
# 175  fahim moshin shaikh  shailendra singh
# 179  fahim moshin shaikh   diptikanta jena
# 182  fahim moshin shaikh  shailendra singh
# 183  fahim moshin shaikh  shailendra singh
# 184  fahim moshin shaikh  shailendra singh
# 191  fahim moshin shaikh  shailendra singh
# 195  fahim moshin shaikh  shailendra singh
# 200  fahim moshin shaikh  shailendra singh
# 222  fahim moshin shaikh  shailendra singh
# 242  fahim moshin shaikh  shailendra singh
# 243  fahim moshin shaikh  shailendra singh
#
#                               prospect_id          status
# 41   2aaf1986-3363-425e-997c-09eb514aa77c    active token
# 42   ab199ad9-8147-4258-a1d4-99c16aa30f32    active token
# 49   c5f5aa70-ec7f-4fd0-bd73-4ed5773b3746  INACTIVE TOKEN
# 50   b93b53a1-c3dd-4ab9-bfa8-6c41fd5a4c55  INACTIVE TOKEN
# 55   73b9de59-bd11-11ee-807d-02e22ea38447    active token
# 74   4d5275e2-4502-4422-8146-4d6811ded4de    active token
# 78   18822671-78e7-4394-a8df-e54287a8cdb4    active token
# 87   a35f638b-4ee8-11ee-a17b-0a9468bc4542  INACTIVE TOKEN
# 89   907e5cdf-5b7d-11ee-a17b-0a9468bc4542  INACTIVE TOKEN
# 91   a34e2f9c-4ee8-11ee-a17b-0a9468bc4542  INACTIVE TOKEN
# 102  3b134a40-9cee-40a8-a0da-ee82dc7005cd  INACTIVE TOKEN
# 111  d108390a-cb8c-4876-b2db-efce9e029253    active token
# 123  edf0c9eb-df87-4029-90a3-98f75029f529    active token
# 125  d8ac7e44-8d83-4e73-95d0-6eea495a9ecb    active token
# 132  73ba4142-bd11-11ee-807d-02e22ea38447    active token
# 133  73ba7405-bd11-11ee-807d-02e22ea38447    active token
# 143  637ca4f4-10c0-486a-949d-289b2fb27a40    active token
# 146  885fcbfa-150a-475a-a0c0-ffb0c55219f2    active token
# 147  4a793912-1684-11ee-ad83-0a9468bc4542    active token
# 152  1a952d1d-c1df-4cac-a50b-7f126b2aa3ac    active token
# 155  47b8bf3b-4993-4086-bb3a-27c3d57a5fdc  INACTIVE TOKEN
# 160  b988b21d-5b82-11ee-a17b-0a9468bc4542    active token
# 161  4fd750d1-2f88-45a2-8b6b-33e4ee538909    active token
# 175  a35362cc-4ee8-11ee-a17b-0a9468bc4542    active token
# 179  c95beaba-8245-4007-b849-aba38f4ff350    active token
# 182  bf265122-52c9-11ee-a17b-0a9468bc4542  INACTIVE TOKEN
# 183  bd1025fc-0808-4f78-82dc-7f39ce40e9b1    active token
# 184  9d414d1b-cb43-451a-a2a8-8f96f1289061    active token
# 191  202de6ac-ba84-468f-a50d-89005c8f9a6c    active token
# 195  c9a42c89-2ee7-43f8-b69e-d2e8026963b8    active token
# 200  9392fae7-eb32-41e1-8096-90803f51193b    active token
# 222  9e1b148b-5713-4815-b5da-ce55cc609546    active token
# 242  37db7091-de0b-4539-8776-b99254f38489    active token
# 243  604f72b3-24aa-417a-92d6-00506068f78b    active token

# %%
plt.figure(figsize=(14, 6))
sns.countplot(y='source', data=df1, order=df1['source'].value_counts().index, palette='viridis')
plt.title('Breakdown of Tokens by Source (Without Lead ID)')
plt.xlabel('Count')
plt.ylabel('Source')
plt.show()

# %%
plt.figure(figsize=(14, 6))
sns.countplot(y='source', data=df2, order=df2['source'].value_counts().index, palette='viridis')
plt.title('Breakdown of Tokens by Source (With Lead ID)')
plt.xlabel('Count')
plt.ylabel('Source')
plt.show()

# %%
plt.figure(figsize=(14, 6))
sns.countplot(y='agent', data=df1, order=df1['agent'].value_counts().index, palette='cubehelix')
plt.title('Breakdown of Tokens by Agent (Without Lead ID)')
plt.xlabel('Count')
plt.ylabel('Agent')
plt.show()

# %%
plt.figure(figsize=(14, 6))
sns.countplot(y='agent', data=df2, order=df2['agent'].value_counts().index, palette='cubehelix')
plt.title('Breakdown of Tokens by Agent (With Lead ID)')
plt.xlabel('Count')
plt.ylabel('Agent')
plt.show()

# %% [markdown]
# # Bar Plot of Tokens by Status

# %%
plt.figure(figsize=(14, 6))
sns.countplot(y='status', data=df1, order=df1['status'].value_counts().index, palette='pastel')
plt.title('Tokens by Status (Without Lead ID)')
plt.xlabel('Count')
plt.ylabel('Status')
plt.show()

plt.figure(figsize=(14, 6))
sns.countplot(y='status', data=df2, order=df2['status'].value_counts().index, palette='pastel')
plt.title('Tokens by Status (With Lead ID)')
plt.xlabel('Count')
plt.ylabel('Status')
plt.show()

# %% [markdown]
# # Count of records per source

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df1, x='source', order=df1['source'].value_counts().index)
plt.xticks(rotation=90)
plt.title('Count of Records per Source')
plt.show()

# %% [markdown]
# # Number of tokens paid over time

# %%
tokens_per_date = df1['paid_date'].value_counts().sort_index()
plt.figure(figsize=(10, 6))
tokens_per_date.plot(kind='line')
plt.title('Number of Tokens Paid Over Time')
plt.xlabel('Paid Date')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Distribution of status

# %%
status_counts = df1['status'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(status_counts, labels=status_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Status')
plt.show()

# %% [markdown]
# # Distribution of token payment delay

# %%
df1['created_date'] = pd.to_datetime(df1['created_date'])
df1['paid_date'] = pd.to_datetime(df1['paid_date'])

df1['payment_delay'] = (df1['paid_date'] - df1['created_date']).dt.days
plt.figure(figsize=(10, 6))
sns.boxplot(data=df1, x='cohort', y='payment_delay')
plt.title('Distribution of Token Payment Delay per Cohort')
plt.xlabel('Cohort')
plt.ylabel('Payment Delay (days)')
plt.show()

# %%
df1['created_date'] = pd.to_datetime(df1['created_date'])
df1['paid_date'] = pd.to_datetime(df1['paid_date'])
df1['payment_delay'] = (df1['paid_date'] - df1['created_date']).dt.days

sns.pairplot(df1[['payment_delay', 'cohort', 'source']], hue='cohort')
plt.show()

# %%
source_counsellor_pivot = df1.pivot_table(index='source', columns='counsellor', aggfunc='size', fill_value=0)
plt.figure(figsize=(12, 8))
sns.heatmap(source_counsellor_pivot, annot=True, fmt='d', cmap='YlGnBu')
plt.title('Heatmap of Source and Counsellor')
plt.xlabel('Counsellor')
plt.ylabel('Source')
plt.show()

# %% [markdown]
# # Visualization with df2 (With Lead Id)

# %% [markdown]
# # Count of records per agent

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df2, x='agent', order=df2['agent'].value_counts().index)
plt.xticks(rotation=90)
plt.title('Count of Records per Agent')
plt.show()

# %% [markdown]
# # Number of tokens paid over time "paid_date"

# %%
tokens_per_date_df2 = df2['paid_date'].value_counts().sort_index()
plt.figure(figsize=(10, 6))
tokens_per_date_df2.plot(kind='line')
plt.title('Number of Tokens Paid Over Time')
plt.xlabel('Paid Date')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Distribution of token payment delay

# %%
df2['created_date'] = pd.to_datetime(df2['created_date'])
df2['paid_date'] = pd.to_datetime(df2['paid_date'])

df2['payment_delay'] = (df2['paid_date'] - df2['created_date']).dt.days
plt.figure(figsize=(10, 6))
sns.boxplot(data=df2, x='counsellor', y='payment_delay')
plt.title('Distribution of Token Payment Delay per Counsellor')
plt.xlabel('Counsellor')
plt.ylabel('Payment Delay (days)')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.stripplot(data=df2, x='cohort', y='created_date', jitter=True, dodge=True)
plt.xticks(rotation=90)
plt.title('Distribution of Created Date over Cohort')
plt.xlabel('Cohort')
plt.ylabel('Created Date')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.swarmplot(data=df2, x='agent', y='paid_date', hue='cohort')
plt.xticks(rotation=90)
plt.title('Distribution of Paid Date over Agent')
plt.xlabel('Agent')
plt.ylabel('Paid Date')
plt.show()

# %%
# Count plot: Count of records per counsellor colored by source
plt.figure(figsize=(12, 8))
sns.countplot(data=df2, x='counsellor', hue='source', order=df2['counsellor'].value_counts().index)
plt.xticks(rotation=90)
plt.title('Count of Records per Counsellor Colored by Source')
plt.xlabel('Counsellor')
plt.ylabel('Count')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(14, 6))
sns.scatterplot(x='agent', y='status', data=df1, palette='cubehelix')
plt.title('Status vs. Agent (Without Lead ID)')
plt.xlabel('Agent')
plt.ylabel('Status')
plt.xticks(rotation=90)

plt.show()

# %%
plt.figure(figsize=(14, 6))
sns.scatterplot(x='agent', y='status', data=df2)
plt.title('Status vs. Agent (With Lead ID)')
plt.xlabel('Agent')
plt.ylabel('Status')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(14, 6))
sns.scatterplot(x='source', y='status', data=df1, palette='viridis')
plt.title('Status vs. Source (Without Lead ID)')
plt.xlabel('Source')
plt.ylabel('Status')
plt.xticks(rotation=90)
plt.legend(title='Agent')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize=(14, 6))
sns.scatterplot(x='source', y='counsellor', data=df1, hue='status', palette='viridis')
plt.title('Counsellor vs. Source (Without Lead ID)')
plt.xlabel('Source')
plt.ylabel('Counsellor')
plt.xticks(rotation=90)
plt.legend(title='Status')
plt.show()

# %%
plt.figure(figsize=(14, 6))
sns.scatterplot(x='source', y='counsellor', data=df2, hue='status', palette='viridis')
plt.title('Counsellor vs. Source (With Lead ID)')
plt.xlabel('Source')
plt.ylabel('Counsellor')
plt.xticks(rotation=90)
plt.legend(title='Status')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(14, 6))
sns.scatterplot(x='source', y='cohort', data=df1, hue='status', palette='cubehelix')
plt.title('Cohort vs. Source (Without Lead ID)')
plt.xlabel('Source')
plt.ylabel('Cohort')
plt.xticks(rotation=90)
plt.legend(title='Status')
plt.show()

# %%
plt.figure(figsize=(14, 6))
sns.scatterplot(x='cohort', y='source', data=df2, hue='status', palette='cubehelix')
plt.title('Cohort vs. Source (With Lead ID)')
plt.xlabel('Source')
plt.ylabel('Cohort')
plt.xticks(rotation=90)
plt.legend(title='Status')
plt.show()

# %%
def find_outliers(df):
    numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns
    
    Q1 = df[numeric_cols].quantile(0.25)
    Q3 = df[numeric_cols].quantile(0.75)
    IQR = Q3 - Q1
    
    outliers = ((df[numeric_cols] < (Q1 - 1.5 * IQR)) | (df[numeric_cols] > (Q3 + 1.5 * IQR)))
    
    return outliers

outliers_df1 = find_outliers(df1)
outliers_df2 = find_outliers(df2)

print("Outliers in dataset without Lead ID:")
print(df1[outliers_df1.any(axis=1)])

print("\nOutliers in dataset with Lead ID:")
print(df2[outliers_df2.any(axis=1)])
# Out:
# Outliers in dataset without Lead ID:
# Empty DataFrame
# Columns: [Name, created_date, paid_date, cohort, source, agent, counsellor, prospect_id, status]
# Index: []
#
# Outliers in dataset with Lead ID:
# Empty DataFrame
# Columns: [Name, Lead ID, created_date, paid_date, cohort, source, agent, counsellor, prospect_id, status]
# Index: []

# %%
def plot_heatmap(df, title):
    numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns
    if numeric_cols.empty:
        print(f"No numeric columns in the dataset for {title}")
        return

    corr = df[numeric_cols].corr()

    plt.figure(figsize=(10, 8))
    sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
    plt.title(title)
    plt.show()

plot_heatmap(df1, "Heatmap for Dataset without Lead ID")
plot_heatmap(df2, "Heatmap for Dataset with Lead ID")
# Out:
# No numeric columns in the dataset for Heatmap for Dataset without Lead ID
# No numeric columns in the dataset for Heatmap for Dataset with Lead ID
